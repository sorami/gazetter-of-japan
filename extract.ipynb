# %% [markdown]
# # 地名集日本（Gazetteer of Japan）
#
# [sorami/gazetter-of-japan](https://github.com/sorami/gazetter-of-japan)

# %% [markdown]
# - データソース` 000238259.pdf`: 国土地理院 [地名集日本（2021年更新）　(3082KB PDF)](https://www.gsi.go.jp/common/000238259.pdf) (2022-12-22取得)
# - 上記データを加工（PDFをパースし、CSV, JSON形式へ変換）
# - [国土地理院コンテンツ利用規約 | 国土地理院](https://www.gsi.go.jp/kikakuchousei/kikakuchousei40182.html)

# %%
from collections import defaultdict
from decimal import Decimal, ROUND_HALF_EVEN

from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextBoxHorizontal, LTRect
import pandas as pd

# %% [markdown]
# ## PDFの表ページを取得

# %%
# %%time
pdf_pages = [p for p in extract_pages("original/000238259.pdf")]

# PDF: 計112ページ
assert len(pdf_pages) == 112

# 地名表: PDFのページ8 - 111
table_pages = pdf_pages[7:111]
# Out:
# CPU times: user 14.6 s, sys: 220 ms, total: 14.9 s
# Wall time: 15 s

# %% [markdown]
# ## 表ページから各行を取得

# %%
def extract_column(element):
    return [d.get_text().strip() for d in element]

# %%
all_page_columns = {}
error_page_columns = {}

for page_no, page in enumerate(table_pages, start=1):
    elements = [e for e in page]
    
    # Grid列は、分割されているページが多く対応が困難なため、今回は対象外
    page_columns = {
        "Japanese(Kanji)": [],
        "Japanese(Kana)": [],
        "Romanized Japanese": [],
        "Latitude": [],
        "Longitude": [],
         "Classification": []
    }

    # 各列を取得
    for elm in elements:
        if type(elm) != LTTextBoxHorizontal:
            continue

        col = extract_column(elm)
        if col[0] in page_columns:
            page_columns[col[0]] = col[1:]
        elif col[0] == "Latitude Longitude":
            page_columns["Longitude"] = col[1::2]
            page_columns["Latitude"] = col[2::2]
            

    # 各列は、40行からなると想定（最終ページを除く）
    # 上手く列を取得できていないと想定されるページを判定
    # 別途、後段で対応
    if not(
        40 == 
        len(page_columns["Japanese(Kanji)"]) == 
        len(page_columns["Japanese(Kana)"]) == 
        len(page_columns["Romanized Japanese"]) == 
        len(page_columns["Classification"]) == 
        len(page_columns["Latitude"]) == 
        len(page_columns["Longitude"])
    ) and page_no < len(table_pages):
        print(page_no)
        error_page_columns[page_no] = page_columns
    else:
        all_page_columns[page_no] = page_columns
# Out:
# 5
# 35
# 40
# 52
# 75
# 77

# %% [markdown]
# ## 正しく取得できなかったページの対処
#
# 一部の行では、漢字が画像になっているなどのために、正しくパースできない。これらは以下、半手動で対応する。

# %%
print(error_page_columns.keys())
# Out:
# dict_keys([5, 35, 40, 52, 75, 77])

# %%
def check_column_counts(page_column):
    return pd.DataFrame([(k, len(v)) for k, v in page_column.items()], columns=["column", "count"])

# %% [markdown]
# ### ページ5

# %%
check_column_counts(error_page_columns[5])
# Out:
#                column  count
# 0     Japanese(Kanji)     38
# 1      Japanese(Kana)     40
# 2  Romanized Japanese     40
# 3            Latitude     40
# 4           Longitude     40
# 5      Classification     40

# %%
error_page_columns[5]["Japanese(Kanji)"]
# Out:
# ['有福島',
#  '有馬',
#  '有田町',
#  '厚狭川',
#  '阿佐山',
#  'あさぎり町',
#  '朝来市',
#  '朝日町',
#  '旭岳',
#  '朝日岳',
#  '朝日岳',
#  '旭川',
#  '朝日町',
#  '朝日町',
#  '朝日村',
#  '旭市',
#  '旭川市',
#  '朝霞市',
#  '浅川町',
#  '浅口市',
#  '朝倉市',
#  '浅草',
#  '浅草岳',
#  '浅間山',
#  '朝熊ヶ岳',
#  '浅間隠山',
#  '浅虫',
#  '浅瀬石川',
#  '芦辺',
#  '芦別岳',
#  '芦別川',
#  '芦別市',
#  '芦田川',
#  '足利市',
#  '芦北町',
#  '芦ノ湖',
#  '足尾山地',
#  '愛鷹山']

# %% [markdown]
# [芦屋町](https://www.town.ashiya.lg.jp/)

# %% [markdown]
# [芦屋市／芦屋市の「芦」の字の表記について](https://www.city.ashiya.lg.jp/bunsho/documents/ashinojinohyouki.html)
#
# > 質問
# > ホームページや市の刊行物等で芦屋市の「芦」の字が草冠の下の戸の字の一画目が斜め下にはねて表記されるものと、「戸」と表記されているものとで混在していますが、正式にはどちらが正しいのでしょうか。
# >
# > 回答
# > 芦屋市の「芦」の表記の違いについては、デザイン上の差であって、字体の差ではありませんので、公文書等においてはどちらも使用できることとしています。

# %%
assert len(error_page_columns[5]["Japanese(Kanji)"]) == 38
error_page_columns[5]["Japanese(Kanji)"] += ["芦屋町", "芦屋市"]
assert len(error_page_columns[5]["Japanese(Kanji)"]) == 40

# %%
pd.DataFrame(error_page_columns[5])
# Out:
#    Japanese(Kanji) Japanese(Kana) Romanized Japanese Latitude Longitude  \
# 0              有福島         ありふくじま       Arifuku Jima   32°55'   128°57'
# 1               有馬            ありま              Arima   34°48'   135°15'
# 2              有田町         ありたちょう          Arita Cho   33°13'   129°51'
# 3              厚狭川           あさがわ           Asa Gawa   34°00'   131°09'
# 4              阿佐山           あさやま           Asa Yama   34°47'   132°23'
# 5            あさぎり町        あさぎりちょう        Asagiri Cho   32°14'   130°54'
# 6              朝来市           あさごし          Asago Shi   35°20'   134°51'
# 7              朝日町         あさひちょう          Asahi Cho   35°02'   136°40'
# 8               旭岳          あさひだけ         Asahi Dake   43°40'   142°51'
# 9              朝日岳          あさひだけ         Asahi Dake   38°16'   139°55'
# 10             朝日岳          あさひだけ         Asahi Dake   36°50'   137°44'
# 11              旭川          あさひがわ         Asahi Gawa   34°36'   133°58'
# 12             朝日町          あさひまち        Asahi Machi   38°18'   140°09'
# 13             朝日町          あさひまち        Asahi Machi   36°57'   137°34'
# 14             朝日村          あさひむら         Asahi Mura   36°07'   137°52'
# 15              旭市           あさひし          Asahi Shi   35°43'   140°39'
# 16             旭川市         あさひかわし      Asahikawa Shi   43°46'   142°22'
# 17             朝霞市           あさかし          Asaka Shi   35°48'   139°36'
# 18             浅川町         あさかわまち      Asakawa Machi   37°05'   140°25'
# 19             浅口市          あさくちし       Asakuchi Shi   34°32'   133°35'
# 20             朝倉市          あさくらし        Asakura Shi   33°25'   130°40'
# 21              浅草           あさくさ            Asakusa   35°43'   139°48'
# 22             浅草岳         あさくさだけ       Asakusa Dake   37°21'   139°14'
# 23             浅間山          あさまやま         Asama Yama   36°24'   138°31'
# 24            朝熊ヶ岳         あさまがたけ        Asamagatake   34°28'   136°47'
# 25            浅間隠山       あさまかくしやま  Asamakakushi Yama   36°27'   138°39'
# 26              浅虫           あさむし           Asamushi   40°53'   140°52'
# 27            浅瀬石川         あせいしがわ       Aseishi Gawa   40°39'   140°30'
# 28              芦辺            あしべ             Ashibe   33°48'   129°45'
# 29             芦別岳         あしべつだけ     Ashibetsu Dake   43°14'   142°17'
# 30             芦別川         あしべつがわ     Ashibetsu Gawa   43°31'   142°12'
# 31             芦別市          あしべつし      Ashibetsu Shi   43°31'   142°11'
# 32             芦田川          あしだがわ        Ashida Gawa   34°26'   133°24'
# 33             足利市          あしかがし       Ashikaga Shi   36°20'   139°27'
# 34             芦北町         あしきたまち     Ashikita Machi   32°18'   130°30'
# 35             芦ノ湖           あしのこ           Ashinoko   35°13'   139°00'
# 36            足尾山地         あしおさんち       Ashio Sanchi   36°32'   139°30'
# 37             愛鷹山         あしたかやま      Ashitaka Yama   35°14'   138°48'
# 38             芦屋町          あしやまち       Ashiya Machi   33°54'   130°40'
# 39             芦屋市           あしやし         Ashiya Shi   34°44'   135°18'
#
#                Classification
# 0                      Island
# 1              Populated area
# 2                Municipality
# 3                       River
# 4                    Mountain
# 5                Municipality
# 6                Municipality
# 7                Municipality
# 8                    Mountain
# 9                    Mountain
# 10                   Mountain
# 11                      River
# 12               Municipality
# 13               Municipality
# 14               Municipality
# 15               Municipality
# 16               Municipality
# 17               Municipality
# 18               Municipality
# 19               Municipality
# 20               Municipality
# 21             Populated area
# 22                   Mountain
# 23                   Mountain
# 24                   Mountain
# 25                   Mountain
# 26             Populated area
# 27                      River
# 28             Populated area
# 29                   Mountain
# 30                      River
# 31               Municipality
# 32                      River
# 33               Municipality
# 34               Municipality
# 35                       Lake
# 36  Extensive natural feature
# 37                   Mountain
# 38               Municipality
# 39               Municipality

# %%
assert len(error_page_columns[5]["Japanese(Kanji)"]) == 40
all_page_columns[5] = error_page_columns[5]

# %% [markdown]
# ### ページ35

# %%
check_column_counts(error_page_columns[35])
# Out:
#                column  count
# 0     Japanese(Kanji)     15
# 1      Japanese(Kana)     40
# 2  Romanized Japanese     40
# 3            Latitude     40
# 4           Longitude     40
# 5      Classification     40

# %%
error_page_columns[35]["Japanese(Kanji)"]
# Out:
# ['かすみがうら市',
#  '粕屋町',
#  '加太',
#  '潟上市',
#  '傾山',
#  '交野市',
#  '片品川',
#  '片品村',
#  '片山津',
#  '加東市',
#  '香取海山',
#  '香取市',
#  '勝本',
#  'かつらぎ町',
#  '葛城山']

# %% [markdown]
# [葛の字の取り扱い／葛城市](https://www.city.katsuragi.nara.jp/soshiki/kikakuseisakuka/20/3215.html)

# %%
assert len(error_page_columns[35]["Japanese(Kanji)"]) == 15
error_page_columns[35]["Japanese(Kanji)"] += ["葛城市"]

# %%
page = table_pages[35-1]
elements = [e for e in page]
for elm in elements:
    if type(elm) != LTTextBoxHorizontal:
            continue
    col = extract_column(elm)
    if col[0] == "葛尾村":
        print(col)
# Out:
# ['葛尾村', '葛飾区', '勝浦町', '勝浦川', '勝浦海盆', '勝浦海底谷', '勝浦市', '勝山市', '川場村', '川辺町', '川辺川', '河内岳', '河内町', '河内長野市', '川越町', '川越市', '河口湖', '川口市', '河合町', '河地', '川島町', '川尻', '川上村', '川上村']

# %%
assert len(error_page_columns[35]["Japanese(Kanji)"]) == 16
error_page_columns[35]["Japanese(Kanji)"] += \
    ['葛尾村', '葛飾区', '勝浦町', '勝浦川', '勝浦海盆', '勝浦海底谷', '勝浦市', '勝山市', 
     '川場村', '川辺町', '川辺川', '河内岳', '河内町', '河内長野市', 
     '川越町', '川越市', '河口湖', '川口市', '河合町', '河地', '川島町', '川尻', '川上村', '川上村']
assert len(error_page_columns[35]["Japanese(Kanji)"]) == 40

# %%
pd.DataFrame(error_page_columns[35])
# Out:
#    Japanese(Kanji) Japanese(Kana)   Romanized Japanese Latitude Longitude  \
# 0          かすみがうら市        かすみがうらし      Kasumigaura Shi   36°09'   140°14'
# 1              粕屋町          かすやまち         Kasuya Machi   33°37'   130°29'
# 2               加太             かた                 Kata   34°16'   135°05'
# 3              潟上市          かたがみし         Katagami Shi   39°51'   140°01'
# 4               傾山         かたむきやま        Katamuki Yama   32°50'   131°29'
# 5              交野市           かたのし           Katano Shi   34°47'   135°41'
# 6              片品川         かたしながわ       Katashina Gawa   36°37'   139°03'
# 7              片品村         かたしなむら       Katashina Mura   36°46'   139°14'
# 8              片山津          かたやまづ           Katayamazu   36°21'   136°22'
# 9              加東市           かとうし             Kato Shi   34°55'   134°58'
# 10            香取海山        かとりかいざん        Katori Kaizan   36°06'   143°00'
# 11             香取市           かとりし           Katori Shi   35°54'   140°30'
# 12              勝本           かつもと            Katsumoto   33°51'   129°42'
# 13           かつらぎ町        かつらぎちょう        Katsuragi Cho   34°18'   135°30'
# 14             葛城山         かつらぎさん        Katsuragi San   34°21'   135°26'
# 15             葛城市          かつらぎし        Katsuragi Shi   34°29'   135°44'
# 16             葛尾村         かつらおむら        Katsurao Mura   37°30'   140°46'
# 17             葛飾区          かつしかく        Katsushika Ku   35°45'   139°51'
# 18             勝浦町        かつうらちょう         Katsuura Cho   33°56'   134°31'
# 19             勝浦川         かつうらがわ        Katsuura Gawa   34°02'   134°35'
# 20            勝浦海盆       かつうらかいぼん      Katsuura Kaibon   34°21'   141°25'
# 21           勝浦海底谷     かつうらかいていこく  Katsuura Kaiteikoku   34°47'   140°47'
# 22             勝浦市          かつうらし         Katsuura Shi   35°09'   140°19'
# 23             勝山市          かつやまし        Katsuyama Shi   36°04'   136°30'
# 24             川場村          かわばむら          Kawaba Mura   36°42'   139°06'
# 25             川辺町         かわべちょう           Kawabe Cho   35°29'   137°04'
# 26             川辺川          かわべがわ          Kawabe Gawa   32°12'   130°48'
# 27             河内岳          かわちだけ         Kawachi Dake   37°13'   136°49'
# 28             河内町          かわちまち        Kawachi Machi   35°53'   140°15'
# 29           河内長野市        かわちながのし    Kawachinagano Shi   34°27'   135°34'
# 30             川越町        かわごえちょう          Kawagoe Cho   35°01'   136°40'
# 31             川越市          かわごえし          Kawagoe Shi   35°56'   139°29'
# 32             河口湖          かわぐちこ         Kawaguchi Ko   35°31'   138°45'
# 33             川口市          かわぐちし        Kawaguchi Shi   35°48'   139°43'
# 34             河合町         かわいちょう            Kawai Cho   34°35'   135°44'
# 35              河地            かわじ               Kawaji   32°49'   131°16'
# 36             川島町         かわじままち       Kawajima Machi   36°00'   139°29'
# 37              川尻           かわじり             Kawajiri   34°14'   132°42'
# 38             川上村         かわかみむら        Kawakami Mura   35°59'   138°35'
# 39             川上村         かわかみむら        Kawakami Mura   34°20'   135°57'
#
#       Classification
# 0       Municipality
# 1       Municipality
# 2     Populated area
# 3       Municipality
# 4           Mountain
# 5       Municipality
# 6              River
# 7       Municipality
# 8     Populated area
# 9       Municipality
# 10  Undersea feature
# 11      Municipality
# 12    Populated area
# 13      Municipality
# 14          Mountain
# 15      Municipality
# 16      Municipality
# 17      Municipality
# 18      Municipality
# 19             River
# 20  Undersea feature
# 21  Undersea feature
# 22      Municipality
# 23      Municipality
# 24      Municipality
# 25      Municipality
# 26             River
# 27          Mountain
# 28      Municipality
# 29      Municipality
# 30      Municipality
# 31      Municipality
# 32              Lake
# 33      Municipality
# 34      Municipality
# 35    Populated area
# 36      Municipality
# 37    Populated area
# 38      Municipality
# 39      Municipality

# %%
assert len(error_page_columns[35]["Japanese(Kanji)"]) == 40
all_page_columns[35] = error_page_columns[35]

# %% [markdown]
# ### ページ40

# %%
check_column_counts(error_page_columns[40])
# Out:
#                column  count
# 0     Japanese(Kanji)      0
# 1      Japanese(Kana)     33
# 2  Romanized Japanese     33
# 3            Latitude     60
# 4           Longitude     60
# 5      Classification     40

# %%
pd.DataFrame(
    zip(error_page_columns[40]["Japanese(Kana)"], error_page_columns[40]["Romanized Japanese"]),
    columns=["Japanese(Kana)", "Romanized Japanese"]
)
# Out:
#    Japanese(Kana) Romanized Japanese
# 0            きつきし        Kitsuki Shi
# 1          きっとやさん        Kittoya San
# 2          きやまちょう         Kiyama Cho
# 3          きよかわむら      Kiyokawa Mura
# 4         きよさとちょう       Kiyosato Cho
# 5            きよせし         Kiyose Shi
# 6            きよすし         Kiyosu Shi
# 7          きよすみやま      Kiyosumi Yama
# 8           きよつがわ       Kiyotsu Gawa
# 9            きづがわ          Kizu Gawa
# 10          きづがわし       Kizugawa Shi
# 11           こうざき            Ko Zaki
# 12          こばやしし      Kobayashi Shi
# 13           こうべし           Kobe Shi
# 14         こぶしがたけ      Kobushigatake
# 15          こうちけん          Kochi Ken
# 16           こうちし          Kochi Shi
# 17            こうだ               Koda
# 18          こだいらし        Kodaira Shi
# 19         こだからじま      Kodakara Jima
# 20        こどまりみさき    Kodomari Misaki
# 21         こえといがわ        Koetoi Gawa
# 22         こうふちょう           Kofu Cho
# 23           こうふし           Kofu Shi
# 24            こがし           Koga Shi
# 25            こがし           Koga Shi
# 26         こがじゃじま        Kogaja Jima
# 27          こがねいし        Koganei Shi
# 28          こうげまち         Koge Machi
# 29          こうござき          Kogo Zaki
# 30            こぐし            Kogushi
# 31          こはまじま        Kohama Jima
# 32       コヒトデかいざん   Ko-Hitode Kaizan

# %%
page = table_pages[40-1]
elements = [e for e in page]
for elm in elements:
    if type(elm) != LTTextBoxHorizontal:
            continue
    col = extract_column(elm)
    print(col)
# Out:
# ['Gazetteer of Japan']
# ['2021']
# ['1561', '1562', '1563', '1564', '1565', '1566', '1567', '1568', '1569', '1570', '1571', '1572', '1573', '1574', '1575', '1576', '1577', '1578', '1579', '1580', '1581', '1582', '1583', '1584', '1585', '1586', '1587', '1588', '1589', '1590', '1591', '1592', '1593', '1594', '1595', '1596', '1597', '1598', '1599', '1600']
# ['Grid', '5031', '5540', '5030', '5339', '6544', '5339', '5236', '5240', '5538', '5235', '5235', '5129', '4830', '5235', '5338', '5033', '5033', '5232', '5339', '4329', '6140', '6841', '5233', '5338', '5439', '5030', '4429', '5339', '5031', '4929', '5130', '3623']
# ['4930', '5339', '5133', '6239']
# ['Japanese(Kana)', 'きつきし', 'きっとやさん', 'きやまちょう', 'きよかわむら', 'きよさとちょう', 'きよせし', 'きよすし', 'きよすみやま', 'きよつがわ', 'きづがわ', 'きづがわし', 'こうざき', 'こばやしし', 'こうべし', 'こぶしがたけ', 'こうちけん', 'こうちし', 'こうだ', 'こだいらし', 'こだからじま', 'こどまりみさき', 'こえといがわ', 'こうふちょう', 'こうふし', 'こがし', 'こがし', 'こがじゃじま', 'こがねいし', 'こうげまち', 'こうござき', 'こぐし', 'こはまじま', 'コヒトデかいざん']
# ['Latitude Longitude', 'Japanese(Kanji)', "131°37'", "33°25'", '杵築市', "140°52'", "37°13'", '屹兎屋山', "130°31'", "33°26'", '基山町', "139°17'", "35°29'", '清川村', "144°36'", "43°50'", '清里町', "139°32'", "35°47'", '清瀬市', "136°51'", "35°12'", '清須市', "140°09'", "35°10'", '清澄山', "138°41'", "37°03'", '清津川', "135°41'", "34°53'", '木津川', "135°49'", "34°44'", '木津川市', "129°13'", "34°05'", '神崎', "130°58'", "32°00'", '小林市', "135°12'", "34°41'", '神戸市', "138°44'", "35°55'", '甲武信ヶ岳', "133°32'", "33°34'", '高知県', "133°32'", "33°34'", '高知市', "132°45'", "34°42'", '甲田', "139°29'", "35°44'", '小平市', "129°20'", "29°13'", '小宝島', "140°15'", "41°07'", '小泊岬', "141°45'", "45°24'", '声問川', "133°29'", "35°17'", '江府町', "138°34'", "35°40'", '甲府市', "139°45'", "36°11'", '古河市', "130°28'", "33°44'", '古賀市', "129°37'", "29°53'", '小臥蛇島', "139°30'", "35°42'", '小金井市', "131°10'", "33°35'", '上毛町', "129°40'", "33°06'", '高後崎', "130°56'", "34°10'", '小串', "123°59'", "24°20'", '小浜島', "154°36'", 'コヒトデ海山', "22°09'", "141°58'", "小日吉海山（八十八夜海山） こひよしかいざん（はちじゅうはちやかいざん） Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan） 23°21'", "135°33'", "26°30'", '高鵬海穴', "135°05'", "26°43'", '高鵬海嶺', "130°09'", "33°13'", '江北町', "139°51'", "35°21'", '小糸川', "133°48'", "34°28'", '児島', "139°48'", "41°22'", '小島']
# ['Romanized Japanese', 'Kitsuki Shi', 'Kittoya San', 'Kiyama Cho', 'Kiyokawa Mura', 'Kiyosato Cho', 'Kiyose Shi', 'Kiyosu Shi', 'Kiyosumi Yama', 'Kiyotsu Gawa', 'Kizu Gawa', 'Kizugawa Shi', 'Ko Zaki', 'Kobayashi Shi', 'Kobe Shi', 'Kobushigatake', 'Kochi Ken', 'Kochi Shi', 'Koda', 'Kodaira Shi', 'Kodakara Jima', 'Kodomari Misaki', 'Koetoi Gawa', 'Kofu Cho', 'Kofu Shi', 'Koga Shi', 'Koga Shi', 'Kogaja Jima', 'Koganei Shi', 'Koge Machi', 'Kogo Zaki', 'Kogushi', 'Kohama Jima', 'Ko-Hitode Kaizan']
# ['こうほうかいけつ', 'こうほうかいれい', 'こうほくまち', 'こいとがわ', 'こじま', 'こじま']
# ['Koho Kaiketsu', 'Koho Kairei', 'Kohoku Machi', 'Koito Gawa', 'Kojima', 'Kojima']
# ['Classification', 'Municipality', 'Mountain', 'Municipality', 'Municipality', 'Municipality', 'Municipality', 'Municipality', 'Mountain', 'River', 'River', 'Municipality', 'Cape', 'Municipality', 'Municipality', 'Mountain', 'Municipality', 'Municipality', 'Populated area', 'Municipality', 'Island', 'Cape', 'River', 'Municipality', 'Municipality', 'Municipality', 'Municipality', 'Island', 'Municipality', 'Municipality', 'Cape', 'Populated area', 'Island', 'Undersea feature', 'Undersea feature', 'Undersea feature', 'Undersea feature', 'Municipality', 'River', 'Populated area', 'Island']
# ['－ 40 －']

# %%
assert len(error_page_columns[40]["Japanese(Kana)"]) == 33
error_page_columns[40]["Japanese(Kana)"] += \
        ["こひよしかいざん（はちじゅうはちやかいざん）"] + \
        ['こうほうかいけつ', 'こうほうかいれい', 'こうほくまち', 'こいとがわ', 'こじま', 'こじま']
assert len(error_page_columns[40]["Japanese(Kana)"]) == 40

# %%
assert len(error_page_columns[40]["Romanized Japanese"]) == 33
error_page_columns[40]["Romanized Japanese"] += \
        ["Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan）"] + \
        ['Koho Kaiketsu', 'Koho Kairei', 'Kohoku Machi', 'Koito Gawa', 'Kojima', 'Kojima']
assert len(error_page_columns[40]["Japanese(Kana)"]) == 40

# %%
pd.DataFrame(
    zip(
        error_page_columns[40]["Japanese(Kana)"],
        error_page_columns[40]["Romanized Japanese"],
        error_page_columns[40]["Classification"]
    ),
    columns=["Japanese(Kana)", "Romanized Japanese", "Classfication"]
)
# Out:
#             Japanese(Kana)                        Romanized Japanese  \
# 0                     きつきし                               Kitsuki Shi
# 1                   きっとやさん                               Kittoya San
# 2                   きやまちょう                                Kiyama Cho
# 3                   きよかわむら                             Kiyokawa Mura
# 4                  きよさとちょう                              Kiyosato Cho
# 5                     きよせし                                Kiyose Shi
# 6                     きよすし                                Kiyosu Shi
# 7                   きよすみやま                             Kiyosumi Yama
# 8                    きよつがわ                              Kiyotsu Gawa
# 9                     きづがわ                                 Kizu Gawa
# 10                   きづがわし                              Kizugawa Shi
# 11                    こうざき                                   Ko Zaki
# 12                   こばやしし                             Kobayashi Shi
# 13                    こうべし                                  Kobe Shi
# 14                  こぶしがたけ                             Kobushigatake
# 15                   こうちけん                                 Kochi Ken
# 16                    こうちし                                 Kochi Shi
# 17                     こうだ                                      Koda
# 18                   こだいらし                               Kodaira Shi
# 19                  こだからじま                             Kodakara Jima
# 20                 こどまりみさき                           Kodomari Misaki
# 21                  こえといがわ                               Koetoi Gawa
# 22                  こうふちょう                                  Kofu Cho
# 23                    こうふし                                  Kofu Shi
# 24                     こがし                                  Koga Shi
# 25                     こがし                                  Koga Shi
# 26                  こがじゃじま                               Kogaja Jima
# 27                   こがねいし                               Koganei Shi
# 28                   こうげまち                                Koge Machi
# 29                   こうござき                                 Kogo Zaki
# 30                     こぐし                                   Kogushi
# 31                   こはまじま                               Kohama Jima
# 32                コヒトデかいざん                          Ko-Hitode Kaizan
# 33  こひよしかいざん（はちじゅうはちやかいざん）  Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan）
# 34                こうほうかいけつ                             Koho Kaiketsu
# 35                こうほうかいれい                               Koho Kairei
# 36                  こうほくまち                              Kohoku Machi
# 37                   こいとがわ                                Koito Gawa
# 38                     こじま                                    Kojima
# 39                     こじま                                    Kojima
#
#        Classfication
# 0       Municipality
# 1           Mountain
# 2       Municipality
# 3       Municipality
# 4       Municipality
# 5       Municipality
# 6       Municipality
# 7           Mountain
# 8              River
# 9              River
# 10      Municipality
# 11              Cape
# 12      Municipality
# 13      Municipality
# 14          Mountain
# 15      Municipality
# 16      Municipality
# 17    Populated area
# 18      Municipality
# 19            Island
# 20              Cape
# 21             River
# 22      Municipality
# 23      Municipality
# 24      Municipality
# 25      Municipality
# 26            Island
# 27      Municipality
# 28      Municipality
# 29              Cape
# 30    Populated area
# 31            Island
# 32  Undersea feature
# 33  Undersea feature
# 34  Undersea feature
# 35  Undersea feature
# 36      Municipality
# 37             River
# 38    Populated area
# 39            Island

# %%
page = table_pages[40-1]
elements = [e for e in page]
for elm in elements:
    if type(elm) != LTTextBoxHorizontal:
            continue
    col = extract_column(elm)
    if col[0] == "Latitude Longitude":
        print(col)
# Out:
# ['Latitude Longitude', 'Japanese(Kanji)', "131°37'", "33°25'", '杵築市', "140°52'", "37°13'", '屹兎屋山', "130°31'", "33°26'", '基山町', "139°17'", "35°29'", '清川村', "144°36'", "43°50'", '清里町', "139°32'", "35°47'", '清瀬市', "136°51'", "35°12'", '清須市', "140°09'", "35°10'", '清澄山', "138°41'", "37°03'", '清津川', "135°41'", "34°53'", '木津川', "135°49'", "34°44'", '木津川市', "129°13'", "34°05'", '神崎', "130°58'", "32°00'", '小林市', "135°12'", "34°41'", '神戸市', "138°44'", "35°55'", '甲武信ヶ岳', "133°32'", "33°34'", '高知県', "133°32'", "33°34'", '高知市', "132°45'", "34°42'", '甲田', "139°29'", "35°44'", '小平市', "129°20'", "29°13'", '小宝島', "140°15'", "41°07'", '小泊岬', "141°45'", "45°24'", '声問川', "133°29'", "35°17'", '江府町', "138°34'", "35°40'", '甲府市', "139°45'", "36°11'", '古河市', "130°28'", "33°44'", '古賀市', "129°37'", "29°53'", '小臥蛇島', "139°30'", "35°42'", '小金井市', "131°10'", "33°35'", '上毛町', "129°40'", "33°06'", '高後崎', "130°56'", "34°10'", '小串', "123°59'", "24°20'", '小浜島', "154°36'", 'コヒトデ海山', "22°09'", "141°58'", "小日吉海山（八十八夜海山） こひよしかいざん（はちじゅうはちやかいざん） Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan） 23°21'", "135°33'", "26°30'", '高鵬海穴', "135°05'", "26°43'", '高鵬海嶺', "130°09'", "33°13'", '江北町', "139°51'", "35°21'", '小糸川', "133°48'", "34°28'", '児島', "139°48'", "41°22'", '小島']

# %%
page_40_lat_lon_col = [
                    'Latitude Longitude', 'Japanese(Kanji)',

                    "131°37'", "33°25'", '杵築市',
                    "140°52'", "37°13'", '屹兎屋山',
                    "130°31'", "33°26'", '基山町',
                    "139°17'", "35°29'", '清川村',
                    "144°36'", "43°50'", '清里町',
                    "139°32'", "35°47'", '清瀬市',
                    "136°51'", "35°12'", '清須市',
                    "140°09'", "35°10'", '清澄山',
                    "138°41'", "37°03'", '清津川',
                    "135°41'", "34°53'", '木津川',
                    "135°49'", "34°44'", '木津川市',
                    "129°13'", "34°05'", '神崎',
                    "130°58'", "32°00'", '小林市',
                    "135°12'", "34°41'", '神戸市',
                    "138°44'", "35°55'", '甲武信ヶ岳',
                    "133°32'", "33°34'", '高知県',
                    "133°32'", "33°34'", '高知市',
                    "132°45'", "34°42'", '甲田',
                    "139°29'", "35°44'", '小平市',
                    "129°20'", "29°13'", '小宝島',
                    "140°15'", "41°07'", '小泊岬',
                    "141°45'", "45°24'", '声問川',
                    "133°29'", "35°17'", '江府町',
                    "138°34'", "35°40'", '甲府市',
                    "139°45'", "36°11'", '古河市',
                    "130°28'", "33°44'", '古賀市',
                    "129°37'", "29°53'", '小臥蛇島',
                    "139°30'", "35°42'", '小金井市',
                    "131°10'", "33°35'", '上毛町',
                    "129°40'", "33°06'", '高後崎',
                    "130°56'", "34°10'", '小串',
                    "123°59'", "24°20'", '小浜島',
    
                    # ズレている
                    "154°36'", 'コヒトデ海山', "22°09'",
    
                    # ズレている、別の列が混入している
                    "141°58'", "小日吉海山（八十八夜海山） こひよしかいざん（はちじゅうはちやかいざん） Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan） 23°21'",

                    "135°33'", "26°30'", '高鵬海穴',
                    "135°05'", "26°43'", '高鵬海嶺',
                    "130°09'", "33°13'", '江北町',
                    "139°51'", "35°21'", '小糸川',
                    "133°48'", "34°28'", '児島',
                    "139°48'", "41°22'", '小島']

# %%
# 人手修正
page_40_lat_lon_col_mod = [
                    # ヘッダー行を人手削除
    
                    "131°37'", "33°25'", '杵築市',
                    "140°52'", "37°13'", '屹兎屋山',
                    "130°31'", "33°26'", '基山町',
                    "139°17'", "35°29'", '清川村',
                    "144°36'", "43°50'", '清里町',
                    "139°32'", "35°47'", '清瀬市',
                    "136°51'", "35°12'", '清須市',
                    "140°09'", "35°10'", '清澄山',
                    "138°41'", "37°03'", '清津川',
                    "135°41'", "34°53'", '木津川',
                    "135°49'", "34°44'", '木津川市',
                    "129°13'", "34°05'", '神崎',
                    "130°58'", "32°00'", '小林市',
                    "135°12'", "34°41'", '神戸市',
                    "138°44'", "35°55'", '甲武信ヶ岳',
                    "133°32'", "33°34'", '高知県',
                    "133°32'", "33°34'", '高知市',
                    "132°45'", "34°42'", '甲田',
                    "139°29'", "35°44'", '小平市',
                    "129°20'", "29°13'", '小宝島',
                    "140°15'", "41°07'", '小泊岬',
                    "141°45'", "45°24'", '声問川',
                    "133°29'", "35°17'", '江府町',
                    "138°34'", "35°40'", '甲府市',
                    "139°45'", "36°11'", '古河市',
                    "130°28'", "33°44'", '古賀市',
                    "129°37'", "29°53'", '小臥蛇島',
                    "139°30'", "35°42'", '小金井市',
                    "131°10'", "33°35'", '上毛町',
                    "129°40'", "33°06'", '高後崎',
                    "130°56'", "34°10'", '小串',
                    "123°59'", "24°20'", '小浜島',
                    "154°36'", "22°09'",  'コヒトデ海山', # 人手修正
                    "141°58'", "23°21'", "小日吉海山（八十八夜海山） ", # 人手修正
                    "135°33'", "26°30'", '高鵬海穴',
                    "135°05'", "26°43'", '高鵬海嶺',
                    "130°09'", "33°13'", '江北町',
                    "139°51'", "35°21'", '小糸川',
                    "133°48'", "34°28'", '児島',
                    "139°48'", "41°22'", '小島']

page_40_lon = page_40_lat_lon_col_mod[0::3]
page_40_lat = page_40_lat_lon_col_mod[1::3]
page_40_kanji = page_40_lat_lon_col_mod[2::3]
assert len(page_40_lon) == len(page_40_lat) == len(page_40_kanji)

error_page_columns[40]["Longitude"] = page_40_lon
error_page_columns[40]["Latitude"] = page_40_lat
error_page_columns[40]["Japanese(Kanji)"] = page_40_kanji

# %%
pd.DataFrame(error_page_columns[40])
# Out:
#    Japanese(Kanji)          Japanese(Kana)  \
# 0              杵築市                    きつきし
# 1             屹兎屋山                  きっとやさん
# 2              基山町                  きやまちょう
# 3              清川村                  きよかわむら
# 4              清里町                 きよさとちょう
# 5              清瀬市                    きよせし
# 6              清須市                    きよすし
# 7              清澄山                  きよすみやま
# 8              清津川                   きよつがわ
# 9              木津川                    きづがわ
# 10            木津川市                   きづがわし
# 11              神崎                    こうざき
# 12             小林市                   こばやしし
# 13             神戸市                    こうべし
# 14           甲武信ヶ岳                  こぶしがたけ
# 15             高知県                   こうちけん
# 16             高知市                    こうちし
# 17              甲田                     こうだ
# 18             小平市                   こだいらし
# 19             小宝島                  こだからじま
# 20             小泊岬                 こどまりみさき
# 21             声問川                  こえといがわ
# 22             江府町                  こうふちょう
# 23             甲府市                    こうふし
# 24             古河市                     こがし
# 25             古賀市                     こがし
# 26            小臥蛇島                  こがじゃじま
# 27            小金井市                   こがねいし
# 28             上毛町                   こうげまち
# 29             高後崎                   こうござき
# 30              小串                     こぐし
# 31             小浜島                   こはまじま
# 32          コヒトデ海山                コヒトデかいざん
# 33  小日吉海山（八十八夜海山）   こひよしかいざん（はちじゅうはちやかいざん）
# 34            高鵬海穴                こうほうかいけつ
# 35            高鵬海嶺                こうほうかいれい
# 36             江北町                  こうほくまち
# 37             小糸川                   こいとがわ
# 38              児島                     こじま
# 39              小島                     こじま
#
#                           Romanized Japanese Latitude Longitude  \
# 0                                Kitsuki Shi   33°25'   131°37'
# 1                                Kittoya San   37°13'   140°52'
# 2                                 Kiyama Cho   33°26'   130°31'
# 3                              Kiyokawa Mura   35°29'   139°17'
# 4                               Kiyosato Cho   43°50'   144°36'
# 5                                 Kiyose Shi   35°47'   139°32'
# 6                                 Kiyosu Shi   35°12'   136°51'
# 7                              Kiyosumi Yama   35°10'   140°09'
# 8                               Kiyotsu Gawa   37°03'   138°41'
# 9                                  Kizu Gawa   34°53'   135°41'
# 10                              Kizugawa Shi   34°44'   135°49'
# 11                                   Ko Zaki   34°05'   129°13'
# 12                             Kobayashi Shi   32°00'   130°58'
# 13                                  Kobe Shi   34°41'   135°12'
# 14                             Kobushigatake   35°55'   138°44'
# 15                                 Kochi Ken   33°34'   133°32'
# 16                                 Kochi Shi   33°34'   133°32'
# 17                                      Koda   34°42'   132°45'
# 18                               Kodaira Shi   35°44'   139°29'
# 19                             Kodakara Jima   29°13'   129°20'
# 20                           Kodomari Misaki   41°07'   140°15'
# 21                               Koetoi Gawa   45°24'   141°45'
# 22                                  Kofu Cho   35°17'   133°29'
# 23                                  Kofu Shi   35°40'   138°34'
# 24                                  Koga Shi   36°11'   139°45'
# 25                                  Koga Shi   33°44'   130°28'
# 26                               Kogaja Jima   29°53'   129°37'
# 27                               Koganei Shi   35°42'   139°30'
# 28                                Koge Machi   33°35'   131°10'
# 29                                 Kogo Zaki   33°06'   129°40'
# 30                                   Kogushi   34°10'   130°56'
# 31                               Kohama Jima   24°20'   123°59'
# 32                          Ko-Hitode Kaizan   22°09'   154°36'
# 33  Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan）   23°21'   141°58'
# 34                             Koho Kaiketsu   26°30'   135°33'
# 35                               Koho Kairei   26°43'   135°05'
# 36                              Kohoku Machi   33°13'   130°09'
# 37                                Koito Gawa   35°21'   139°51'
# 38                                    Kojima   34°28'   133°48'
# 39                                    Kojima   41°22'   139°48'
#
#       Classification
# 0       Municipality
# 1           Mountain
# 2       Municipality
# 3       Municipality
# 4       Municipality
# 5       Municipality
# 6       Municipality
# 7           Mountain
# 8              River
# 9              River
# 10      Municipality
# 11              Cape
# 12      Municipality
# 13      Municipality
# 14          Mountain
# 15      Municipality
# 16      Municipality
# 17    Populated area
# 18      Municipality
# 19            Island
# 20              Cape
# 21             River
# 22      Municipality
# 23      Municipality
# 24      Municipality
# 25      Municipality
# 26            Island
# 27      Municipality
# 28      Municipality
# 29              Cape
# 30    Populated area
# 31            Island
# 32  Undersea feature
# 33  Undersea feature
# 34  Undersea feature
# 35  Undersea feature
# 36      Municipality
# 37             River
# 38    Populated area
# 39            Island

# %%
assert len(error_page_columns[40]["Japanese(Kanji)"]) == 40
all_page_columns[40] = error_page_columns[40]

# %% [markdown]
# ### ページ52

# %%
check_column_counts(error_page_columns[52])
# Out:
#                column  count
# 0     Japanese(Kanji)      4
# 1      Japanese(Kana)     40
# 2  Romanized Japanese     40
# 3            Latitude     40
# 4           Longitude     40
# 5      Classification     40

# %%
error_page_columns[52]["Japanese(Kanji)"]
# Out:
# ['三種町', '三頭山', '水戸市', '三豊市']

# %% [markdown]
# [ホーム／御杖村](https://www.vill.mitsue.nara.jp/)

# %%
assert len(error_page_columns[52]["Japanese(Kanji)"]) == 4
error_page_columns[52]["Japanese(Kanji)"] += ["御杖村"]

# %%
page = table_pages[52-1]
elements = [e for e in page]
for elm in elements:
    if type(elm) != LTTextBoxHorizontal:
            continue
    col = extract_column(elm)
    if col[0] == "三石":
        print(col)
# Out:
# ['三石', '見附市', '三俣蓮華岳', '三ッ島', '美津島', '三ツ峠山', '三浦半島', '三浦市', '宮川', '宮川', '宮田村', '宮城島', '宮城県', '三宅町', '三宅島', '三宅村', 'みやき町', '宮古島', 'みやこ町', '宮古列島', '宮古市', '宮古島市', '都城市', 'みやま市', '宮之浦岳', '宮良海山', '宮代町', '宮塚山', '宮若市', '宮崎県', '宮崎市', '宮崎ノ鼻', '宮津市', '三芳町', 'みよし市']

# %%
assert len(error_page_columns[52]["Japanese(Kanji)"]) == 5
error_page_columns[52]["Japanese(Kanji)"] += \
    ['三石', '見附市', '三俣蓮華岳', '三ッ島', '美津島', '三ツ峠山', '三浦半島', '三浦市',
     '宮川', '宮川', '宮田村', '宮城島', '宮城県', '三宅町', '三宅島', '三宅村', 'みやき町',
     '宮古島', 'みやこ町', '宮古列島', '宮古市', '宮古島市', '都城市', 'みやま市', '宮之浦岳',
     '宮良海山', '宮代町', '宮塚山', '宮若市', '宮崎県', '宮崎市', '宮崎ノ鼻', '宮津市', '三芳町', 'みよし市']
assert len(error_page_columns[52]["Japanese(Kanji)"]) == 40

# %%
pd.DataFrame(error_page_columns[52])
# Out:
#    Japanese(Kanji) Japanese(Kana)   Romanized Japanese Latitude Longitude  \
# 0              三種町         みたねちょう           Mitane Cho   40°06'   140°00'
# 1              三頭山          みとうさん             Mito San   35°44'   139°01'
# 2              水戸市            みとし             Mito Shi   36°22'   140°28'
# 3              三豊市           みとよし           Mitoyo Shi   34°11'   133°43'
# 4              御杖村          みつえむら          Mitsue Mura   34°29'   136°10'
# 5               三石           みついし            Mitsuishi   34°48'   134°16'
# 6              見附市           みつけし          Mitsuke Shi   37°32'   138°55'
# 7            三俣蓮華岳      みつまたれんげだけ  Mitsumatarenge Dake   36°23'   137°35'
# 8              三ッ島           みつしま           Mitsushima   34°43'   129°27'
# 9              美津島           みつしま           Mitsushima   34°16'   129°19'
# 10            三ツ峠山        みつとうげやま       Mitsutoge Yama   35°33'   138°49'
# 11            三浦半島        みうらはんとう          Miura Hanto   35°19'   139°35'
# 12             三浦市           みうらし            Miura Shi   35°09'   139°37'
# 13              宮川           みやがわ            Miya Gawa   36°28'   137°15'
# 14              宮川           みやがわ            Miya Gawa   34°32'   136°44'
# 15             宮田村          みやだむら          Miyada Mura   35°46'   137°57'
# 16             宮城島          みやぎじま          Miyagi Jima   26°22'   127°59'
# 17             宮城県          みやぎけん           Miyagi Ken   38°16'   140°52'
# 18             三宅町         みやけちょう           Miyake Cho   34°34'   135°46'
# 19             三宅島          みやけじま          Miyake Jima   34°05'   139°31'
# 20             三宅村          みやけむら          Miyake Mura   34°05'   139°29'
# 21            みやき町         みやきちょう           Miyaki Cho   33°19'   130°27'
# 22             宮古島          みやこじま          Miyako Jima   24°47'   125°18'
# 23            みやこ町          みやこまち         Miyako Machi   33°42'   130°55'
# 24            宮古列島        みやこれっとう         Miyako Retto   24°36'   125°06'
# 25             宮古市           みやこし           Miyako Shi   39°38'   141°57'
# 26            宮古島市         みやこじまし       Miyakojima Shi   24°48'   125°17'
# 27             都城市       みやこのじょうし       Miyakonojo Shi   31°43'   131°04'
# 28            みやま市           みやまし           Miyama Shi   33°09'   130°28'
# 29            宮之浦岳        みやのうらだけ       Miyanoura Dake   30°20'   130°30'
# 30            宮良海山        みやらかいざん        Miyara Kaizan   22°07'   125°09'
# 31             宮代町         みやしろまち      Miyashiro Machi   36°01'   139°43'
# 32             宮塚山         みやつかやま       Miyatsuka Yama   34°31'   139°17'
# 33             宮若市          みやわかし         Miyawaka Shi   33°43'   130°40'
# 34             宮崎県         みやざきけん         Miyazaki Ken   31°55'   131°25'
# 35             宮崎市          みやざきし         Miyazaki Shi   31°54'   131°25'
# 36            宮崎ノ鼻        みやざきのはな       Miyazakinohana   34°05'   135°05'
# 37             宮津市           みやづし           Miyazu Shi   35°32'   135°12'
# 38             三芳町          みよしまち        Miyoshi Machi   35°50'   139°32'
# 39            みよし市           みよしし          Miyoshi Shi   35°05'   137°04'
#
#                Classification
# 0                Municipality
# 1                    Mountain
# 2                Municipality
# 3                Municipality
# 4                Municipality
# 5              Populated area
# 6                Municipality
# 7                    Mountain
# 8                      Island
# 9              Populated area
# 10                   Mountain
# 11  Extensive natural feature
# 12               Municipality
# 13                      River
# 14                      River
# 15               Municipality
# 16                     Island
# 17               Municipality
# 18               Municipality
# 19                     Island
# 20               Municipality
# 21               Municipality
# 22                     Island
# 23               Municipality
# 24  Extensive natural feature
# 25               Municipality
# 26               Municipality
# 27               Municipality
# 28               Municipality
# 29                   Mountain
# 30           Undersea feature
# 31               Municipality
# 32                   Mountain
# 33               Municipality
# 34               Municipality
# 35               Municipality
# 36                       Cape
# 37               Municipality
# 38               Municipality
# 39               Municipality

# %%
assert len(error_page_columns[52]["Japanese(Kanji)"]) == 40
all_page_columns[52] = error_page_columns[52]

# %% [markdown]
# ### ページ75

# %%
check_column_counts(error_page_columns[75])
# Out:
#                column  count
# 0     Japanese(Kanji)     39
# 1      Japanese(Kana)     40
# 2  Romanized Japanese     40
# 3            Latitude     40
# 4           Longitude     40
# 5      Classification     40

# %%
error_page_columns[75]["Japanese(Kanji)"]
# Out:
# ['三条市',
#  '山上ヶ岳',
#  '傘寿海山',
#  '山武市',
#  '三戸町',
#  '佐野市',
#  '三福海山',
#  '三嶺',
#  '讃岐山脈',
#  'さぬき市',
#  '三和',
#  '山陽小野田市',
#  '棹崎',
#  '札幌岳',
#  '札幌市',
#  '更別村',
#  'サロベツ川',
#  '佐呂間町',
#  'サロマ湖',
#  '佐呂間別川',
#  '沙流川',
#  '猿払川',
#  '猿払村',
#  '猿ヶ石川',
#  '猿山岬',
#  '笹山',
#  '篠山',
#  '笹ヶ峰',
#  '笹子峠',
#  '篠栗町',
#  '笹谷峠',
#  '佐世保市',
#  '指臼山',
#  '佐多岬',
#  '里庄町',
#  '皐月海山',
#  'さつま町',
#  '薩摩半島',
#  '薩摩海山']

# %% [markdown]
# [薩摩川内市](https://www.city.satsumasendai.lg.jp/www/index.html)

# %%
assert len(error_page_columns[75]["Japanese(Kanji)"]) == 39
error_page_columns[75]["Japanese(Kanji)"] += ["薩摩川内市"]
assert len(error_page_columns[75]["Japanese(Kanji)"]) == 40

# %%
pd.DataFrame(error_page_columns[75])
# Out:
#    Japanese(Kanji) Japanese(Kana) Romanized Japanese Latitude Longitude  \
# 0              三条市         さんじょうし          Sanjo Shi   37°38'   138°58'
# 1             山上ヶ岳       さんじょうがたけ        Sanjogatake   34°15'   135°56'
# 2             傘寿海山       さんじゅかいざん       Sanju Kaizan   25°00'   134°05'
# 3              山武市           さんむし          Sanmu Shi   35°36'   140°25'
# 4              三戸町         さんのへまち      Sannohe Machi   40°23'   141°16'
# 5              佐野市            さのし           Sano Shi   36°19'   139°35'
# 6             三福海山       さんぷくかいざん     Sanpuku Kaizan   22°49'   142°42'
# 7               三嶺           さんれい             Sanrei   33°50'   133°59'
# 8             讃岐山脈       さぬきさんみゃく    Sanuki Sanmyaku   34°10'   134°08'
# 9             さぬき市           さぬきし         Sanuki Shi   34°20'   134°10'
# 10              三和            さんわ              Sanwa   34°40'   132°51'
# 11          山陽小野田市       さんようおのだし   San-yo-onoda Shi   34°00'   131°11'
# 12              棹崎           さおざき           Sao Zaki   34°39'   129°19'
# 13             札幌岳         さっぽろだけ       Sapporo Dake   42°54'   141°12'
# 14             札幌市          さっぽろし        Sapporo Shi   43°04'   141°21'
# 15             更別村         さらべつむら     Sarabetsu Mura   42°39'   143°11'
# 16           サロベツ川         サロベツがわ     Sarobetsu Gawa   44°58'   141°45'
# 17            佐呂間町         さろまちょう         Saroma Cho   44°01'   143°46'
# 18            サロマ湖           サロマこ          Saroma Ko   44°08'   143°48'
# 19           佐呂間別川        さろまべつがわ   Saromabetsu Gawa   44°05'   143°56'
# 20             沙流川           さるがわ          Saru Gawa   42°30'   142°01'
# 21             猿払川         さるふつがわ     Sarufutsu Gawa   45°17'   142°14'
# 22             猿払村         さるふつむら     Sarufutsu Mura   45°20'   142°07'
# 23            猿ヶ石川        さるかいしがわ    Sarukaishi Gawa   39°24'   141°08'
# 24             猿山岬        さるやまみさき    Saruyama Misaki   37°19'   136°43'
# 25              笹山           ささやま          Sasa Yama   35°16'   138°17'
# 26              篠山           ささやま          Sasa Yama   33°03'   132°40'
# 27             笹ヶ峰          ささがみね         Sasagamine   33°50'   133°16'
# 28             笹子峠         ささごとうげ        Sasago Toge   35°37'   138°47'
# 29             篠栗町         ささぐりまち     Sasaguri Machi   33°37'   130°32'
# 30             笹谷峠         ささやとうげ        Sasaya Toge   38°14'   140°28'
# 31            佐世保市           させぼし         Sasebo Shi   33°11'   129°43'
# 32             指臼山         さしうすやま      Sashiusu Yama   45°06'   148°01'
# 33             佐多岬          さたみさき        Sata Misaki   31°00'   130°40'
# 34             里庄町       さとしょうちょう        Satosho Cho   34°31'   133°33'
# 35            皐月海山        さつきかいざん     Satsuki Kaizan   23°31'   134°43'
# 36            さつま町         さつまちょう        Satsuma Cho   31°54'   130°27'
# 37            薩摩半島        さつまはんとう      Satsuma Hanto   31°24'   130°27'
# 38            薩摩海山        さつまかいざん     Satsuma Kaizan   27°07'   134°13'
# 39           薩摩川内市       さつませんだいし  Satsumasendai Shi   31°49'   130°18'
#
#                Classification
# 0                Municipality
# 1                    Mountain
# 2            Undersea feature
# 3                Municipality
# 4                Municipality
# 5                Municipality
# 6            Undersea feature
# 7                    Mountain
# 8   Extensive natural feature
# 9                Municipality
# 10             Populated area
# 11               Municipality
# 12                       Cape
# 13                   Mountain
# 14               Municipality
# 15               Municipality
# 16                      River
# 17               Municipality
# 18                       Lake
# 19                      River
# 20                      River
# 21                      River
# 22               Municipality
# 23                      River
# 24                       Cape
# 25                   Mountain
# 26                   Mountain
# 27                   Mountain
# 28                       Pass
# 29               Municipality
# 30                       Pass
# 31               Municipality
# 32                   Mountain
# 33                       Cape
# 34               Municipality
# 35           Undersea feature
# 36               Municipality
# 37  Extensive natural feature
# 38           Undersea feature
# 39               Municipality

# %%
assert len(error_page_columns[75]["Japanese(Kanji)"]) == 40
all_page_columns[75] = error_page_columns[75]

# %% [markdown]
# ### ページ77

# %%
check_column_counts(error_page_columns[77])
# Out:
#                column  count
# 0     Japanese(Kanji)     10
# 1      Japanese(Kana)     40
# 2  Romanized Japanese     40
# 3            Latitude     40
# 4           Longitude     40
# 5      Classification     40

# %%
error_page_columns[77]["Japanese(Kanji)"]
# Out:
# ['瀬戸内町', '瀬戸内市', '摂津市', '雪裡川', '釈迦岳', '釈迦ヶ岳', '釈迦ヶ鼻', '積丹町', '積丹半島', '積丹岬']

# %% [markdown]
# - [北海道紗那郡紗那村 (01699A1968) | 歴史的行政区域データセットβ版](https://geoshape.ex.nii.ac.jp/city/resource/01699A1968.html)
# - [紗那村 - Wikipedia](https://ja.wikipedia.org/wiki/%E7%B4%97%E9%82%A3%E6%9D%91)

# %%
assert len(error_page_columns[77]["Japanese(Kanji)"]) == 10
error_page_columns[77]["Japanese(Kanji)"] += ["紗那村"]

# %%
page = table_pages[77-1]
elements = [e for e in page]
for elm in elements:
    if type(elm) != LTTextBoxHorizontal:
            continue
    col = extract_column(elm)
    if col[0] == "社日海山":
        print(col)
# Out:
# ['社日海山', '斜里町', '斜里岳', '斜里川', '柴田町', '新発田市', '芝山町', '標茶町', '蘂取岳', '蘂取岬', '蘂取村', '標津町', '標津岳', '標津川', '士別市', '士別峠', '紫尾山', '志発島', '渋峠', '渋川市', '渋海川', '志布志市', '志布志湾', '至仏山', '渋谷', '渋谷区', '七ヶ浜町', '七ヶ宿町', '七面山']

# %%
assert len(error_page_columns[77]["Japanese(Kanji)"]) == 11
error_page_columns[77]["Japanese(Kanji)"] += \
    ['社日海山', '斜里町', '斜里岳', '斜里川', '柴田町', '新発田市', '芝山町',
     '標茶町', '蘂取岳', '蘂取岬', '蘂取村', '標津町', '標津岳', '標津川',
     '士別市', '士別峠', '紫尾山', '志発島', '渋峠', '渋川市', '渋海川',
     '志布志市', '志布志湾', '至仏山', '渋谷', '渋谷区', '七ヶ浜町', '七ヶ宿町', '七面山']
assert len(error_page_columns[77]["Japanese(Kanji)"]) == 40

# %%
pd.DataFrame(error_page_columns[77])
# Out:
#    Japanese(Kanji) Japanese(Kana)   Romanized Japanese Latitude Longitude  \
# 0             瀬戸内町        せとうちちょう         Setouchi Cho   28°09'   129°19'
# 1             瀬戸内市          せとうちし         Setouchi Shi   34°40'   134°06'
# 2              摂津市           せっつし           Settsu Shi   34°47'   135°34'
# 3              雪裡川         せっつりがわ        Settsuri Gawa   43°04'   144°24'
# 4              釈迦岳          しゃかだけ           Shaka Dake   33°11'   130°53'
# 5             釈迦ヶ岳         しゃかがだけ          Shakagadake   34°07'   135°54'
# 6             釈迦ヶ鼻         しゃかがはな          Shakagahana   34°25'   134°14'
# 7              積丹町       しゃこたんちょう         Shakotan Cho   43°18'   140°36'
# 8             積丹半島      しゃこたんはんとう       Shakotan Hanto   43°11'   140°32'
# 9              積丹岬       しゃこたんみさき      Shakotan Misaki   43°22'   140°28'
# 10             紗那村          しゃなむら           Shana Mura   45°13'   147°52'
# 11            社日海山       しゃにちかいざん      Shanichi Kaizan   22°44'   141°40'
# 12             斜里町         しゃりちょう            Shari Cho   43°55'   144°40'
# 13             斜里岳          しゃりだけ           Shari Dake   43°46'   144°43'
# 14             斜里川          しゃりがわ           Shari Gawa   43°55'   144°40'
# 15             柴田町          しばたまち        Shibata Machi   38°03'   140°46'
# 16            新発田市           しばたし          Shibata Shi   37°57'   139°20'
# 17             芝山町         しばやままち      Shibayama Machi   35°42'   140°25'
# 18             標茶町        しべちゃちょう         Shibecha Cho   43°18'   144°36'
# 19             蘂取岳         しべとろだけ       Shibetoro Dake   45°24'   148°35'
# 20             蘂取岬        しべとろみさき     Shibetoro Misaki   45°32'   148°39'
# 21             蘂取村         しべとろむら       Shibetoro Mura   45°28'   148°37'
# 22             標津町         しべつちょう         Shibetsu Cho   43°40'   145°08'
# 23             標津岳          しべつだけ        Shibetsu Dake   43°40'   144°42'
# 24             標津川          しべつがわ        Shibetsu Gawa   43°40'   145°08'
# 25             士別市           しべつし         Shibetsu Shi   44°11'   142°24'
# 26             士別峠         しべつとうげ        Shibetsu Toge   44°13'   142°12'
# 27             紫尾山           しびさん            Shibi San   31°59'   130°22'
# 28             志発島          しぼつとう          Shibotsu To   43°31'   146°08'
# 29              渋峠          しぶとうげ           Shibu Toge   36°40'   138°32'
# 30             渋川市          しぶかわし        Shibukawa Shi   36°29'   139°00'
# 31             渋海川          しぶみがわ         Shibumi Gawa   37°26'   138°50'
# 32            志布志市           しぶしし         Shibushi Shi   31°30'   131°03'
# 33            志布志湾          しぶしわん         Shibushi Wan   31°24'   131°08'
# 34             至仏山          しぶつさん         Shibutsu San   36°54'   139°10'
# 35              渋谷            しぶや              Shibuya   35°39'   139°42'
# 36             渋谷区           しぶやく           Shibuya Ku   35°40'   139°42'
# 37            七ヶ浜町        しちがはままち   Shichigahama Machi   38°18'   141°04'
# 38            七ヶ宿町       しちかしゅくまち  Shichikashuku Machi   38°00'   140°26'
# 39             七面山         しちめんざん        Shichimen Zan   35°22'   138°21'
#
#                Classification
# 0                Municipality
# 1                Municipality
# 2                Municipality
# 3                       River
# 4                    Mountain
# 5                    Mountain
# 6                        Cape
# 7                Municipality
# 8   Extensive natural feature
# 9                        Cape
# 10               Municipality
# 11           Undersea feature
# 12               Municipality
# 13                   Mountain
# 14                      River
# 15               Municipality
# 16               Municipality
# 17               Municipality
# 18               Municipality
# 19                   Mountain
# 20                       Cape
# 21               Municipality
# 22               Municipality
# 23                   Mountain
# 24                      River
# 25               Municipality
# 26                       Pass
# 27                   Mountain
# 28                     Island
# 29                       Pass
# 30               Municipality
# 31                      River
# 32               Municipality
# 33                   Sea Area
# 34                   Mountain
# 35             Populated area
# 36               Municipality
# 37               Municipality
# 38               Municipality
# 39                   Mountain

# %%
assert len(error_page_columns[77]["Japanese(Kanji)"]) == 40
all_page_columns[77] = error_page_columns[77]

# %% [markdown]
# ## 取得情報の集約

# %%
d4df = defaultdict(list)
for page_no, page_columns in sorted(all_page_columns.items()):
    for k, v in page_columns.items():
        d4df[k] += v

df_raw = pd.DataFrame(d4df)
df_raw
# Out:
#      Japanese(Kanji) Japanese(Kana) Romanized Japanese Latitude Longitude  \
# 0                網走川         あばしりがわ      Abashiri Gawa   44°01'   144°17'
# 1                網走湖          あばしりこ        Abashiri Ko   43°58'   144°11'
# 2                網走市          あばしりし       Abashiri Shi   44°01'   144°16'
# 3                安倍川           あべかわ           Abe Kawa   34°56'   138°24'
# 4               我孫子市           あびこし          Abiko Shi   35°52'   140°02'
# ...              ...            ...                ...      ...       ...
# 4118              銭洲            ぜにす            Zeni Su   33°57'   138°50'
# 4119            銭洲海嶺        ぜにすかいれい      Zenisu Kairei   33°42'   138°30'
# 4120           銭洲沖海山      ぜにすおきかいざん  Zenisu-Oki Kaizan   33°26'   138°25'
# 4121            善通寺市         ぜんつうじし       Zentsuji Shi   34°14'   133°47'
# 4122             逗子市            ずしし          Zushi Shi   35°18'   139°35'
#
#         Classification
# 0                River
# 1                 Lake
# 2         Municipality
# 3                River
# 4         Municipality
# ...                ...
# 4118            Island
# 4119  Undersea feature
# 4120  Undersea feature
# 4121      Municipality
# 4122      Municipality
#
# [4123 rows x 6 columns]

# %%
def degree_minute_to_decimal(text):
    """
    緯度経度を、度分（60進法）から10進法へ変換
    データは「分」までのため、小数第3位精度へ丸め
    （"1/60 = 0.01666666..." のため、小数第3位程度が妥当と判断）
    """
    assert "°" in text
    assert text.endswith("'")
    text = text[:-1]
    parts = text.split("°")
    assert len(parts) == 2

    degree = Decimal(parts[0])
    minute = Decimal(parts[1])
    return (degree + minute / 60).quantize(Decimal(".001"), ROUND_HALF_EVEN)

# %%
df_mod = df_raw.copy()
df_mod["Latitude"] = df_mod["Latitude"].apply(degree_minute_to_decimal)
df_mod["Longitude"] = df_mod["Longitude"].apply(degree_minute_to_decimal)
df_mod.columns = ["kanji", "kana", "roman", "lat", "lng", "class"]
df_mod
# Out:
#       kanji       kana              roman     lat      lng             class
# 0       網走川     あばしりがわ      Abashiri Gawa  44.017  144.283             River
# 1       網走湖      あばしりこ        Abashiri Ko  43.967  144.183              Lake
# 2       網走市      あばしりし       Abashiri Shi  44.017  144.267      Municipality
# 3       安倍川       あべかわ           Abe Kawa  34.933  138.400             River
# 4      我孫子市       あびこし          Abiko Shi  35.867  140.033      Municipality
# ...     ...        ...                ...     ...      ...               ...
# 4118     銭洲        ぜにす            Zeni Su  33.950  138.833            Island
# 4119   銭洲海嶺    ぜにすかいれい      Zenisu Kairei  33.700  138.500  Undersea feature
# 4120  銭洲沖海山  ぜにすおきかいざん  Zenisu-Oki Kaizan  33.433  138.417  Undersea feature
# 4121   善通寺市     ぜんつうじし       Zentsuji Shi  34.233  133.783      Municipality
# 4122    逗子市        ずしし          Zushi Shi  35.300  139.583      Municipality
#
# [4123 rows x 6 columns]

# %%
# 計4,123行を想定
# = (40行　*103ページ) + 最終ページ3行
# PDFページ111、表の最終行でのカウントも"4123"
assert df_mod.shape[0] == 4123, df_mod.shape[0]

# %% [markdown]
# # 別称（括弧書き）の分割

# %% [markdown]
# - 部分的に別表記のあるケースもある
#   - `火山（硫黄）列島	かざん（いおう）れっとう`
#   - → `火山列島`, `硫黄列島`
#   - [火山列島 - Wikipedia](https://ja.wikipedia.org/wiki/%E7%81%AB%E5%B1%B1%E5%88%97%E5%B3%B6)
# - 漢字表記は複数あるが、読みは一つ、というケースもある
#     - `沖の島（沖ノ島）	おきのしま`
# - 漢字表記は一つだが、読みが複数、というケースもある
#     - `蔵王山	ざおうざん（ざおうさん）`

# %%
def detect_bracket_rows(row):
    for d in (row["kanji"], row["kana"], row["roman"]):
        if "(" in d:
            return True
        elif "（" in d:
            return True
        elif ")" in d:
            return True
        elif "）" in d:
            return True
    return False

# %%
df_mod[df_mod.apply(detect_bracket_rows, axis=1)].reset_index(drop=True)
# Out:
#              kanji                    kana  \
# 0        烏帽子岳（乳頭山）          えぼしだけ（にゅうとうざん）
# 1          冨崎（観音埼）             ふさき（かんのんさき）
# 2         江の川（可愛川）             ごうのかわ（えのかわ）
# 3         階上岳（種市岳）          はしかみだけ（たねいちだけ）
# 4        速日の峰（二子山）           はやひのみね（ふたごやま）
# 5       速吸瀬戸（豊予海峡）        はやすいせと（ほうよかいきょう）
# 6        氷ノ山（須賀ノ山）           ひょうのせん（すがのせん）
# 7           厳島（宮島）             いつくしま（みやじま）
# 8         冠着山（姨捨山）          かむりきやま（おばすてやま）
# 9         火山（硫黄）列島            かざん（いおう）れっとう
# 10  小日吉海山（八十八夜海山）   こひよしかいざん（はちじゅうはちやかいざん）
# 11        小島（八丈小島）           こじま（はちじょうこじま）
# 12       高社山（高井富士）           こうしゃさん（たかいふじ）
# 13         琴引山（弥山）             ことびきさん（みせん）
# 14        琴平山（象頭山）           ことひらやま（ぞうずさん）
# 15       草垣群島（草垣島）        くさがきぐんとう（くさかきしま）
# 16       能郷白山（権現山）        のうごうはくさん（ごんげんざん）
# 17        沖の島（沖ノ島）                   おきのしま
# 18          御岳（北岳）              おんたけ（きただけ）
# 19       大野原島（三本嶽）         おおのはらじま（さんぼんたけ）
# 20        小瀬川（木野川）              おぜがわ（このがわ）
# 21     友ヶ島水道（紀淡海峡）     ともがしますいどう（きたんかいきょう）
# 22        内浦湾（噴火湾）           うちうらわん（ふんかわん）
# 23       由布岳（豊後富士）             ゆふだけ（ぶんごふじ）
# 24       遊楽部岳（見市岳）         ゆうらっぷだけ（けんいちだけ）
# 25             蔵王山            ざおうざん（ざおうさん）
#
#                                        roman     lat      lng  \
# 0                    Eboshi Dake (Nyuto Zan)  39.800  140.833
# 1                      Fu Saki (Kannon Saki)  24.367  124.117
# 2                        Gonokawa (Eno Kawa)  34.800  132.833
# 3             Hashikami Dake (Taneichi Dake)  40.400  141.583
# 4                 Hayahinomine (Futago Yama)  32.567  131.467
# 5                 Hayasui Seto (Hoyo Kaikyo)  33.317  131.983
# 6                       Hyonosen (Suganosen)  35.350  134.517
# 7                    Itsukushima (Miya Jima)  34.267  132.300
# 8               Kamuriki Yama (Obasute Yama)  36.467  138.100
# 9                           Kazan (Io) Retto  24.883  141.467
# 10  Ko-Hiyoshi Kaizan（Hachijuhachiya Kaizan）  23.350  141.967
# 11                   Kojima (Hachijo Kojima)  33.133  139.683
# 12                    Kosha San (Takai Fuji)  36.800  138.400
# 13                      Kotobiki San (Misen)  35.050  132.783
# 14                  Kotohira Yama (Zozu San)  34.183  133.800
# 15           Kusagaki Gunto (Kusakaki Shima)  30.883  129.450
# 16                 Nogo-hakusan (Gongen Zan)  35.767  136.517
# 17                                Okinoshima  32.733  132.550
# 18                        On Take (Kitadake)  31.600  130.650
# 19                Onohara Jima (Sanbon Take)  34.050  139.383
# 20                      Oze Gawa (Kono Gawa)  34.217  132.250
# 21          Tomogashima Suido (Kitan Kaikyo)  34.283  134.967
# 22                   Uchiura Wan (Funka Wan)  42.350  140.633
# 23                    Yufu Dake (Bungo Fuji)  33.283  131.383
# 24              Yurappu Dake (Ken-ichi Dake)  42.217  140.017
# 25                         Zao Zan (Zao San)  38.133  140.450
#
#                         class
# 0                    Mountain
# 1                        Cape
# 2                       River
# 3                    Mountain
# 4                    Mountain
# 5                    Sea Area
# 6                    Mountain
# 7                      Island
# 8                    Mountain
# 9   Extensive natural feature
# 10           Undersea feature
# 11                     Island
# 12                   Mountain
# 13                   Mountain
# 14                   Mountain
# 15  Extensive natural feature
# 16                   Mountain
# 17                     Island
# 18                   Mountain
# 19                     Island
# 20                      River
# 21                   Sea Area
# 22                   Sea Area
# 23                   Mountain
# 24                   Mountain
# 25                   Mountain

# %%
def has_bracket(d):
    for name in (d["kanji"], d["kana"], d["roman"]):
        if "(" in name:
            return True
        elif "（" in name:
            return True
        elif ")" in name:
            return True
        elif "）" in name:
            return True
    return False

# %%
l4df = []

for index, row in df_mod.iterrows():
    d = row.to_dict()
    if not has_bracket(d):
        l4df.append(d)
        continue

    elif d["kanji"].endswith("）") and d["kana"].endswith("）") and d["roman"].endswith(")"):
            assert d["kanji"].count("（") == 1
            assert d["kana"].count("（") == 1
            assert d["roman"].count("(") == 1
            kanjis = d["kanji"][:-1].split("（")
            kanas = d["kana"][:-1].split("（")
            romans = d["roman"][:-1].split("(")
            for x, y, z in zip(kanjis, kanas, romans):
                item = {
                    "kanji": x,
                    "kana": y,
                    "roman": z,
                    "lat": d["lat"],
                    "lng": d["lng"],
                    "class": d["class"]
                }
                print(item)
                l4df.append(item)
    elif d["kanji"] == "火山（硫黄）列島":
        kanjis = ["火山列島", "硫黄列島"]
        kanas = ["かざんれっとう", "いおうれっとう"]
        romans = ["Kazan Retto", "Io Retto"]
        for x, y, z in zip(kanjis, kanas, romans):
                item = {
                    "kanji": x,
                    "kana": y,
                    "roman": z,
                    "lat": d["lat"],
                    "lng": d["lng"],
                    "class": d["class"]
                }
                print(item)
                l4df.append(item)
    elif d["kanji"] == "小日吉海山（八十八夜海山） ":
        assert d["roman"].endswith("）") # 全角括弧
        kanjis = ["小日吉海山", "八十八夜海山"]
        kanas = ["こひよしかいざん", "はちじゅうはちやかいざん"]
        romans = ["Ko-Hiyoshi Kaizan", "Hachijuhachiya Kaizan"]
        for x, y, z in zip(kanjis, kanas, romans):
                item = {
                    "kanji": x,
                    "kana": y,
                    "roman": z,
                    "lat": d["lat"],
                    "lng": d["lng"],
                    "class": d["class"]
                }
                print(item)
                l4df.append(item)
    elif d["kanji"] == "沖の島（沖ノ島）":
        kanjis = ["沖の島", "沖ノ島"]
        kanas = ["おきのしま", "おきのしま"]
        romans = ["Okinoshima", "Okinoshima"]
        for x, y, z in zip(kanjis, kanas, romans):
                item = {
                    "kanji": x,
                    "kana": y,
                    "roman": z,
                    "lat": d["lat"],
                    "lng": d["lng"],
                    "class": d["class"]
                }
                print(item)
                l4df.append(item)
    elif d["kanji"] == "蔵王山":
        kanjis = ["蔵王山", "蔵王山"]
        kanas = ["ざおうざん", "ざおうさん"]
        romans = ["Zao Zan", "Zao San"]
        for x, y, z in zip(kanjis, kanas, romans):
                item = {
                    "kanji": x,
                    "kana": y,
                    "roman": z,
                    "lat": d["lat"],
                    "lng": d["lng"],
                    "class": d["class"]
                }
                print(item)
                l4df.append(item)
    else:
        raise Exception(d)
# Out:
# {'kanji': '烏帽子岳', 'kana': 'えぼしだけ', 'roman': 'Eboshi Dake ', 'lat': Decimal('39.800'), 'lng': Decimal('140.833'), 'class': 'Mountain'}
# {'kanji': '乳頭山', 'kana': 'にゅうとうざん', 'roman': 'Nyuto Zan', 'lat': Decimal('39.800'), 'lng': Decimal('140.833'), 'class': 'Mountain'}
# {'kanji': '冨崎', 'kana': 'ふさき', 'roman': 'Fu Saki ', 'lat': Decimal('24.367'), 'lng': Decimal('124.117'), 'class': 'Cape'}
# {'kanji': '観音埼', 'kana': 'かんのんさき', 'roman': 'Kannon Saki', 'lat': Decimal('24.367'), 'lng': Decimal('124.117'), 'class': 'Cape'}
# {'kanji': '江の川', 'kana': 'ごうのかわ', 'roman': 'Gonokawa ', 'lat': Decimal('34.800'), 'lng': Decimal('132.833'), 'class': 'River'}
# {'kanji': '可愛川', 'kana': 'えのかわ', 'roman': 'Eno Kawa', 'lat': Decimal('34.800'), 'lng': Decimal('132.833'), 'class': 'River'}
# {'kanji': '階上岳', 'kana': 'はしかみだけ', 'roman': 'Hashikami Dake ', 'lat': Decimal('40.400'), 'lng': Decimal('141.583'), 'class': 'Mountain'}
# {'kanji': '種市岳', 'kana': 'たねいちだけ', 'roman': 'Taneichi Dake', 'lat': Decimal('40.400'), 'lng': Decimal('141.583'), 'class': 'Mountain'}
# {'kanji': '速日の峰', 'kana': 'はやひのみね', 'roman': 'Hayahinomine ', 'lat': Decimal('32.567'), 'lng': Decimal('131.467'), 'class': 'Mountain'}
# {'kanji': '二子山', 'kana': 'ふたごやま', 'roman': 'Futago Yama', 'lat': Decimal('32.567'), 'lng': Decimal('131.467'), 'class': 'Mountain'}
# {'kanji': '速吸瀬戸', 'kana': 'はやすいせと', 'roman': 'Hayasui Seto ', 'lat': Decimal('33.317'), 'lng': Decimal('131.983'), 'class': 'Sea Area'}
# {'kanji': '豊予海峡', 'kana': 'ほうよかいきょう', 'roman': 'Hoyo Kaikyo', 'lat': Decimal('33.317'), 'lng': Decimal('131.983'), 'class': 'Sea Area'}
# {'kanji': '氷ノ山', 'kana': 'ひょうのせん', 'roman': 'Hyonosen ', 'lat': Decimal('35.350'), 'lng': Decimal('134.517'), 'class': 'Mountain'}
# {'kanji': '須賀ノ山', 'kana': 'すがのせん', 'roman': 'Suganosen', 'lat': Decimal('35.350'), 'lng': Decimal('134.517'), 'class': 'Mountain'}
# {'kanji': '厳島', 'kana': 'いつくしま', 'roman': 'Itsukushima ', 'lat': Decimal('34.267'), 'lng': Decimal('132.300'), 'class': 'Island'}
# {'kanji': '宮島', 'kana': 'みやじま', 'roman': 'Miya Jima', 'lat': Decimal('34.267'), 'lng': Decimal('132.300'), 'class': 'Island'}
# {'kanji': '冠着山', 'kana': 'かむりきやま', 'roman': 'Kamuriki Yama ', 'lat': Decimal('36.467'), 'lng': Decimal('138.100'), 'class': 'Mountain'}
# {'kanji': '姨捨山', 'kana': 'おばすてやま', 'roman': 'Obasute Yama', 'lat': Decimal('36.467'), 'lng': Decimal('138.100'), 'class': 'Mountain'}
# {'kanji': '火山列島', 'kana': 'かざんれっとう', 'roman': 'Kazan Retto', 'lat': Decimal('24.883'), 'lng': Decimal('141.467'), 'class': 'Extensive natural feature'}
# {'kanji': '硫黄列島', 'kana': 'いおうれっとう', 'roman': 'Io Retto', 'lat': Decimal('24.883'), 'lng': Decimal('141.467'), 'class': 'Extensive natural feature'}
# {'kanji': '小日吉海山', 'kana': 'こひよしかいざん', 'roman': 'Ko-Hiyoshi Kaizan', 'lat': Decimal('23.350'), 'lng': Decimal('141.967'), 'class': 'Undersea feature'}
# {'kanji': '八十八夜海山', 'kana': 'はちじゅうはちやかいざん', 'roman': 'Hachijuhachiya Kaizan', 'lat': Decimal('23.350'), 'lng': Decimal('141.967'), 'class': 'Undersea feature'}
# {'kanji': '小島', 'kana': 'こじま', 'roman': 'Kojima ', 'lat': Decimal('33.133'), 'lng': Decimal('139.683'), 'class': 'Island'}
# {'kanji': '八丈小島', 'kana': 'はちじょうこじま', 'roman': 'Hachijo Kojima', 'lat': Decimal('33.133'), 'lng': Decimal('139.683'), 'class': 'Island'}
# {'kanji': '高社山', 'kana': 'こうしゃさん', 'roman': 'Kosha San ', 'lat': Decimal('36.800'), 'lng': Decimal('138.400'), 'class': 'Mountain'}
# {'kanji': '高井富士', 'kana': 'たかいふじ', 'roman': 'Takai Fuji', 'lat': Decimal('36.800'), 'lng': Decimal('138.400'), 'class': 'Mountain'}
# {'kanji': '琴引山', 'kana': 'ことびきさん', 'roman': 'Kotobiki San ', 'lat': Decimal('35.050'), 'lng': Decimal('132.783'), 'class': 'Mountain'}
# {'kanji': '弥山', 'kana': 'みせん', 'roman': 'Misen', 'lat': Decimal('35.050'), 'lng': Decimal('132.783'), 'class': 'Mountain'}
# {'kanji': '琴平山', 'kana': 'ことひらやま', 'roman': 'Kotohira Yama ', 'lat': Decimal('34.183'), 'lng': Decimal('133.800'), 'class': 'Mountain'}
# {'kanji': '象頭山', 'kana': 'ぞうずさん', 'roman': 'Zozu San', 'lat': Decimal('34.183'), 'lng': Decimal('133.800'), 'class': 'Mountain'}
# {'kanji': '草垣群島', 'kana': 'くさがきぐんとう', 'roman': 'Kusagaki Gunto ', 'lat': Decimal('30.883'), 'lng': Decimal('129.450'), 'class': 'Extensive natural feature'}
# {'kanji': '草垣島', 'kana': 'くさかきしま', 'roman': 'Kusakaki Shima', 'lat': Decimal('30.883'), 'lng': Decimal('129.450'), 'class': 'Extensive natural feature'}
# {'kanji': '能郷白山', 'kana': 'のうごうはくさん', 'roman': 'Nogo-hakusan ', 'lat': Decimal('35.767'), 'lng': Decimal('136.517'), 'class': 'Mountain'}
# {'kanji': '権現山', 'kana': 'ごんげんざん', 'roman': 'Gongen Zan', 'lat': Decimal('35.767'), 'lng': Decimal('136.517'), 'class': 'Mountain'}
# {'kanji': '沖の島', 'kana': 'おきのしま', 'roman': 'Okinoshima', 'lat': Decimal('32.733'), 'lng': Decimal('132.550'), 'class': 'Island'}
# {'kanji': '沖ノ島', 'kana': 'おきのしま', 'roman': 'Okinoshima', 'lat': Decimal('32.733'), 'lng': Decimal('132.550'), 'class': 'Island'}
# {'kanji': '御岳', 'kana': 'おんたけ', 'roman': 'On Take ', 'lat': Decimal('31.600'), 'lng': Decimal('130.650'), 'class': 'Mountain'}
# {'kanji': '北岳', 'kana': 'きただけ', 'roman': 'Kitadake', 'lat': Decimal('31.600'), 'lng': Decimal('130.650'), 'class': 'Mountain'}
# {'kanji': '大野原島', 'kana': 'おおのはらじま', 'roman': 'Onohara Jima ', 'lat': Decimal('34.050'), 'lng': Decimal('139.383'), 'class': 'Island'}
# {'kanji': '三本嶽', 'kana': 'さんぼんたけ', 'roman': 'Sanbon Take', 'lat': Decimal('34.050'), 'lng': Decimal('139.383'), 'class': 'Island'}
# {'kanji': '小瀬川', 'kana': 'おぜがわ', 'roman': 'Oze Gawa ', 'lat': Decimal('34.217'), 'lng': Decimal('132.250'), 'class': 'River'}
# {'kanji': '木野川', 'kana': 'このがわ', 'roman': 'Kono Gawa', 'lat': Decimal('34.217'), 'lng': Decimal('132.250'), 'class': 'River'}
# {'kanji': '友ヶ島水道', 'kana': 'ともがしますいどう', 'roman': 'Tomogashima Suido ', 'lat': Decimal('34.283'), 'lng': Decimal('134.967'), 'class': 'Sea Area'}
# {'kanji': '紀淡海峡', 'kana': 'きたんかいきょう', 'roman': 'Kitan Kaikyo', 'lat': Decimal('34.283'), 'lng': Decimal('134.967'), 'class': 'Sea Area'}
# {'kanji': '内浦湾', 'kana': 'うちうらわん', 'roman': 'Uchiura Wan ', 'lat': Decimal('42.350'), 'lng': Decimal('140.633'), 'class': 'Sea Area'}
# {'kanji': '噴火湾', 'kana': 'ふんかわん', 'roman': 'Funka Wan', 'lat': Decimal('42.350'), 'lng': Decimal('140.633'), 'class': 'Sea Area'}
# {'kanji': '由布岳', 'kana': 'ゆふだけ', 'roman': 'Yufu Dake ', 'lat': Decimal('33.283'), 'lng': Decimal('131.383'), 'class': 'Mountain'}
# {'kanji': '豊後富士', 'kana': 'ぶんごふじ', 'roman': 'Bungo Fuji', 'lat': Decimal('33.283'), 'lng': Decimal('131.383'), 'class': 'Mountain'}
# {'kanji': '遊楽部岳', 'kana': 'ゆうらっぷだけ', 'roman': 'Yurappu Dake ', 'lat': Decimal('42.217'), 'lng': Decimal('140.017'), 'class': 'Mountain'}
# {'kanji': '見市岳', 'kana': 'けんいちだけ', 'roman': 'Ken-ichi Dake', 'lat': Decimal('42.217'), 'lng': Decimal('140.017'), 'class': 'Mountain'}
# {'kanji': '蔵王山', 'kana': 'ざおうざん', 'roman': 'Zao Zan', 'lat': Decimal('38.133'), 'lng': Decimal('140.450'), 'class': 'Mountain'}
# {'kanji': '蔵王山', 'kana': 'ざおうさん', 'roman': 'Zao San', 'lat': Decimal('38.133'), 'lng': Decimal('140.450'), 'class': 'Mountain'}

# %%
df_mod_split = pd.DataFrame(l4df)
assert df_mod_split.shape[0] == 4149 # 4123行+26の分割された行
df_mod_split
# Out:
#       kanji       kana              roman     lat      lng             class
# 0       網走川     あばしりがわ      Abashiri Gawa  44.017  144.283             River
# 1       網走湖      あばしりこ        Abashiri Ko  43.967  144.183              Lake
# 2       網走市      あばしりし       Abashiri Shi  44.017  144.267      Municipality
# 3       安倍川       あべかわ           Abe Kawa  34.933  138.400             River
# 4      我孫子市       あびこし          Abiko Shi  35.867  140.033      Municipality
# ...     ...        ...                ...     ...      ...               ...
# 4144     銭洲        ぜにす            Zeni Su  33.950  138.833            Island
# 4145   銭洲海嶺    ぜにすかいれい      Zenisu Kairei  33.700  138.500  Undersea feature
# 4146  銭洲沖海山  ぜにすおきかいざん  Zenisu-Oki Kaizan  33.433  138.417  Undersea feature
# 4147   善通寺市     ぜんつうじし       Zentsuji Shi  34.233  133.783      Municipality
# 4148    逗子市        ずしし          Zushi Shi  35.300  139.583      Municipality
#
# [4149 rows x 6 columns]

# %% [markdown]
# ## 保存

# %%
df_mod_split.to_csv(
    "gazetteer-of-japan.csv",
    index=False
)

# %%
# !wc -l gazetteer-of-japan.csv
# Out:
#     4150 gazetteer-of-japan.csv

# %%
# !head gazetteer-of-japan.csv
# Out:
# kanji,kana,roman,lat,lng,class
# 網走川,あばしりがわ,Abashiri Gawa,44.017,144.283,River
# 網走湖,あばしりこ,Abashiri Ko,43.967,144.183,Lake
# 網走市,あばしりし,Abashiri Shi,44.017,144.267,Municipality
# 安倍川,あべかわ,Abe Kawa,34.933,138.400,River
# 我孫子市,あびこし,Abiko Shi,35.867,140.033,Municipality
# 安平町,あびらちょう,Abira Cho,42.767,141.817,Municipality
# 安平川,あびらがわ,Abira Gawa,42.617,141.733,River
# 安房峠,あぼうとうげ,Abo Toge,36.200,137.583,Pass
# 阿武町,あぶちょう,Abu Cho,34.500,131.467,Municipality

# %%
df_mod_split.to_json(
    "gazetteer-of-japan.json",
    orient="records",
    double_precision=3,
    force_ascii=False,
    indent=2,
)

# %%
# !head -20 ./gazetteer-of-japan.json
# Out:
# [
#   {
#     "kanji":"網走川",
#     "kana":"あばしりがわ",
#     "roman":"Abashiri Gawa",
#     "lat":44.017,
#     "lng":144.283,
#     "class":"River"
#   },
#   {
#     "kanji":"網走湖",
#     "kana":"あばしりこ",
#     "roman":"Abashiri Ko",
#     "lat":43.967,
#     "lng":144.183,
#     "class":"Lake"
#   },
#   {
#     "kanji":"網走市",
#     "kana":"あばしりし",
